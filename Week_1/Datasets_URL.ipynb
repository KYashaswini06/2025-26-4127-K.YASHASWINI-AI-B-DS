# %% [markdown]
# <a href="https://colab.research.google.com/github/KYashaswini06/2025-26-4127-K.YASHASWINI-AI-B-DS/blob/main/Week_1/Datasets_URL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Downloading , saving and transforming the datasets into a CSV file
import pandas as pd
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df=pd.read_csv(url)
print(df.head())
df.to_csv(r"d:\iris_dataset.csv",index=False)
print("Dataset saved successfully to local drive!")
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Dataset saved successfully to local drive!
